# %% [markdown]
# #                                            🏏 IPL Cricket Analysis 📊

# %% [markdown]
# 1. INTRODUCTION
# 2. DATA IMPORT
# 3. DATA MERGING
# 4. DATA PREPROCESSING & CLEANING
# 5. EXPORT PROCESSED DATA FOR POWER BI
# 6. CONCLUSION

# %% [markdown]
# ## 📌1.INTRODUCTION

# %% [raw]
# PROJECT OVERVIEW:
# Objective:
#    The goal of this project is to analyze IPL match data using Pandas for data processing and Power BI for visualization. We will extract meaningful insights.

# %% [markdown]
# ##### DATA SET OVERVIEW :

# %% [markdown]
# https://www.kaggle.com/datasets/patrickb1912/ipl-complete-dataset-20082020

# %% [markdown]
# ## 📂2.DATA IMPORT

# %% [raw]
# Import datasets (matches.csv and deliveries.csv)

# %%
import os 
os.chdir("C:\\Users\\clinton\\OneDrive\\Desktop\\data set")
! dir
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 8426-E09B
#
#  Directory of C:\Users\clinton\OneDrive\Desktop\data set
#
# 22-03-2025  21:11    <DIR>          .
# 22-03-2025  23:57    <DIR>          ..
# 14-03-2025  23:12            19,751 Car Sales India 2024.xlsx
# 20-03-2025  13:15           240,745 cleaned ipl.csv
# 18-03-2025  19:20            10,790 COUNTRY.xlsx
# 18-03-2025  11:00             8,999 COUNTRYYY.xlsx
# 20-03-2025  17:36             9,061 count_ds.xlsx
# 18-03-2025  11:08        27,019,953 deliveries.csv
# 21-03-2025  10:54            76,813 employee_performance.csv
# 11-03-2025  15:39            25,211 filter data covid.csv
# 22-03-2025  22:23    <DIR>          ipl
# 22-03-2025  21:11        85,268,097 ipl cricket analysis project.csv
# 22-03-2025  21:09        85,268,097 ipl project.csv
# 18-03-2025  11:08           225,266 matches.csv
# 07-03-2025  23:51        23,738,470 Online Retail Data.xlsx
# 11-03-2025  16:25        48,233,998 only 2011.csv
# ...

# %%
import pandas as pd

# %%
matches=pd.read_csv("matches.csv")
deliveries=pd.read_csv('deliveries.csv')

# %%
matches.head() #View the first 5 rows of the DataFrame.
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
matches.shape #Get the dimensions of the DataFrame.
# Out:
# (1095, 20)

# %%
matches.info() #Get a summary of the DataFrame.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
# ...

# %%
matches.describe() #Summary statistics for numerical columns.
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.095000e+03    1076.000000  1092.000000   1092.000000
# mean   9.048283e+05      17.259294   165.684066     19.759341
# std    3.677402e+05      21.787444    33.427048      1.581108
# min    3.359820e+05       1.000000    43.000000      5.000000
# 25%    5.483315e+05       6.000000   146.000000     20.000000
# 50%    9.809610e+05       8.000000   166.000000     20.000000
# 75%    1.254062e+06      20.000000   187.000000     20.000000
# max    1.426312e+06     146.000000   288.000000     20.000000

# %%
matches.isnull().sum() #Check for null values.
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
deliveries.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
deliveries.shape
# Out:
# (260920, 17)

# %%
deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    12950 non-null   object
# ...

# %%
deliveries.describe()
# Out:
#            match_id         inning           over           ball  \
# count  2.609200e+05  260920.000000  260920.000000  260920.000000
# mean   9.070665e+05       1.483531       9.197677       3.624486
# std    3.679913e+05       0.502643       5.683484       1.814920
# min    3.359820e+05       1.000000       0.000000       1.000000
# 25%    5.483340e+05       1.000000       4.000000       2.000000
# 50%    9.809670e+05       1.000000       9.000000       4.000000
# 75%    1.254066e+06       2.000000      14.000000       5.000000
# max    1.426312e+06       6.000000      19.000000      11.000000
#
#         batsman_runs     extra_runs     total_runs      is_wicket
# count  260920.000000  260920.000000  260920.000000  260920.000000
# mean        1.265001       0.067806       1.332807       0.049632
# std         1.639298       0.343265       1.626416       0.217184
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
deliveries.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batter                   0
# bowler                   0
# non_striker              0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# extras_type         246795
# is_wicket                0
# player_dismissed    247970
# dismissal_kind      247970
# fielder             251566
# dtype: int64

# %% [markdown]
# # 📂3.DATA MERGING

# %% [markdown]
# ### Merge season info into deliveries dataset using 'match_id'

# %%
ipl= deliveries.merge(
    matches,
    left_on='match_id',  # Column from `deliveries` to merge on
    right_on='id',       # Column from `matches` to merge on
    how='left'           # Left join: keeps all rows from `deliveries`, adds matching rows from `matches`
)

# %%
ipl
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %% [markdown]
# # 🧹4.DATA PREPROCESSING & CLEANING

# %%
ipl.shape
# Out:
# (260920, 37)

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 37 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    12950 non-null   object
# ...

# %%
ipl.describe()
# Out:
#            match_id         inning           over           ball  \
# count  2.609200e+05  260920.000000  260920.000000  260920.000000
# mean   9.070665e+05       1.483531       9.197677       3.624486
# std    3.679913e+05       0.502643       5.683484       1.814920
# min    3.359820e+05       1.000000       0.000000       1.000000
# 25%    5.483340e+05       1.000000       4.000000       2.000000
# 50%    9.809670e+05       1.000000       9.000000       4.000000
# 75%    1.254066e+06       2.000000      14.000000       5.000000
# max    1.426312e+06       6.000000      19.000000      11.000000
#
#         batsman_runs     extra_runs     total_runs      is_wicket  \
# count  260920.000000  260920.000000  260920.000000  260920.000000
# mean        1.265001       0.067806       1.332807       0.049632
# std         1.639298       0.343265       1.626416       0.217184
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# ## 🔍 Count of Missing Values in Each Column before cleaning

# %%
ipl.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batter                   0
# bowler                   0
# non_striker              0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# extras_type         246795
# is_wicket                0
# player_dismissed    247970
# dismissal_kind      247970
# fielder             251566
# id                       0
# season                   0
# city                 12397
# date                     0
# match_type               0
# player_of_match        490
# venue                    0
# team1                    0
# team2                    0
# toss_winner              0
# toss_decision            0
# winner                 490
# result                   0
# result_margin         4124
# target_runs            309
# target_overs           309
# super_over               0
# ...

# %%
ipl.isnull().sum()[ipl.isnull().sum() > 0]
# Out:
# extras_type         246795
# player_dismissed    247970
# dismissal_kind      247970
# fielder             251566
# city                 12397
# player_of_match        490
# winner                 490
# result_margin         4124
# target_runs            309
# target_overs           309
# method              257274
# dtype: int64

# %% [markdown]
# ### cleaning null values in column:

# %%
# viewing null values in extras_type column (as rows):
ipl['extras_type']
ipl['extras_type'].isnull()
ipl[ipl['extras_type'].isnull()].head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 5    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 7    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     1
#
#    ball       batter   bowler non_striker  batsman_runs  ...  toss_decision  \
# 1     2  BB McCullum  P Kumar  SC Ganguly             0  ...          field
# 3     4  BB McCullum  P Kumar  SC Ganguly             0  ...          field
# 4     5  BB McCullum  P Kumar  SC Ganguly             0  ...          field
# 5     6  BB McCullum  P Kumar  SC Ganguly             0  ...          field
# 7     1  BB McCullum   Z Khan  SC Ganguly             0  ...          field
#
# ...

# %%
#Number of null values in extras_type column:
print("Null values in extras_type column :",ipl['extras_type'].isnull().sum())
# Out:
# Null values in extras_type column : 246795

# %%
ipl['extras_type'].fillna('not avaialble',inplace=True)
# Out:
# C:\Users\clinton\AppData\Local\Temp\ipykernel_14332\3623104714.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ipl['extras_type'].fillna('not avaialble',inplace=True)

# %%
#Number of null values in extras_type column:
print("Null values in extras_type column after cleaning:",ipl['extras_type'].isnull().sum())
# Out:
# Null values in extras_type column after cleaning: 0

# %%
ipl[['extras_type']].head()
# Out:
#      extras_type
# 0        legbyes
# 1  not avaialble
# 2          wides
# 3  not avaialble
# 4  not avaialble

# %%
#------------

# %%
# viewing null values in result_margin column (as rows):
ipl['result_margin']
ipl['result_margin'].isnull()
ipl[ipl['result_margin'].isnull()].head()
# Out:
#        match_id  inning      batting_team           bowling_team  over  ball  \
# 15161    392190       1  Rajasthan Royals  Kolkata Knight Riders     0     1
# 15162    392190       1  Rajasthan Royals  Kolkata Knight Riders     0     2
# 15163    392190       1  Rajasthan Royals  Kolkata Knight Riders     0     3
# 15164    392190       1  Rajasthan Royals  Kolkata Knight Riders     0     4
# 15165    392190       1  Rajasthan Royals  Kolkata Knight Riders     0     5
#
#             batter    bowler  non_striker  batsman_runs  ...  toss_decision  \
# 15161     GC Smith  I Sharma  PC Valthaty             0  ...          field
# 15162     GC Smith  I Sharma  PC Valthaty             0  ...          field
# 15163  PC Valthaty  I Sharma     GC Smith             1  ...          field
# 15164     GC Smith  I Sharma  PC Valthaty             0  ...          field
# 15165     GC Smith  I Sharma  PC Valthaty             0  ...          field
#
# ...

# %%
#Number of null values in result_margin column:
print("Null values in result_margin column :",ipl['result_margin'].isnull().sum())
# Out:
# Null values in result_margin column : 4124

# %%
ipl['result_margin'].fillna(0.0,inplace=True)
# Out:
# C:\Users\clinton\AppData\Local\Temp\ipykernel_14332\2135303393.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ipl['result_margin'].fillna(0.0,inplace=True)

# %%
#Number of null values in result_margin column:
print("Null values in result_margin column after cleaning:",ipl['result_margin'].isnull().sum())
# Out:
# Null values in result_margin column after cleaning: 0

# %%
#--------------

# %%
# viewing null values in target_runs column (as rows):
ipl['target_runs']
ipl['target_runs'].isnull()
ipl[ipl['target_runs'].isnull()].head()
# Out:
#        match_id  inning      batting_team   bowling_team  over  ball  \
# 57068    501265       1  Delhi Daredevils  Pune Warriors     0     1
# 57069    501265       1  Delhi Daredevils  Pune Warriors     0     2
# 57070    501265       1  Delhi Daredevils  Pune Warriors     0     3
# 57071    501265       1  Delhi Daredevils  Pune Warriors     0     4
# 57072    501265       1  Delhi Daredevils  Pune Warriors     0     5
#
#           batter     bowler non_striker  batsman_runs  ...  toss_decision  \
# 57068    NV Ojha  AC Thomas   DA Warner             1  ...            bat
# 57069  DA Warner  AC Thomas     NV Ojha             0  ...            bat
# 57070    NV Ojha  AC Thomas   DA Warner             0  ...            bat
# 57071    NV Ojha  AC Thomas   DA Warner             0  ...            bat
# 57072    NV Ojha  AC Thomas   DA Warner             0  ...            bat
#
#        winner     result  result_margin target_runs target_overs super_over  \
# ...

# %%
#Number of null values in target_runs column:
print("Null values in target_runs column :",ipl['target_runs'].isnull().sum())
# Out:
# Null values in target_runs column : 309

# %%
ipl['target_runs'].fillna(0.0,inplace=True)
# Out:
# C:\Users\clinton\AppData\Local\Temp\ipykernel_14332\201232652.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ipl['target_runs'].fillna(0.0,inplace=True)

# %%
#Number of null values in target_runs column:
print("Null values in target_runs column after cleaning:",ipl['target_runs'].isnull().sum())
# Out:
# Null values in target_runs column after cleaning: 0

# %%
#----------------

# %%
# viewing the null value rows in traget_overs column:
ipl['target_overs']
ipl['target_overs'].isnull()
ipl[ipl['target_overs'].isnull()].head()
# Out:
#        match_id  inning      batting_team   bowling_team  over  ball  \
# 57068    501265       1  Delhi Daredevils  Pune Warriors     0     1
# 57069    501265       1  Delhi Daredevils  Pune Warriors     0     2
# 57070    501265       1  Delhi Daredevils  Pune Warriors     0     3
# 57071    501265       1  Delhi Daredevils  Pune Warriors     0     4
# 57072    501265       1  Delhi Daredevils  Pune Warriors     0     5
#
#           batter     bowler non_striker  batsman_runs  ...  toss_decision  \
# 57068    NV Ojha  AC Thomas   DA Warner             1  ...            bat
# 57069  DA Warner  AC Thomas     NV Ojha             0  ...            bat
# 57070    NV Ojha  AC Thomas   DA Warner             0  ...            bat
# 57071    NV Ojha  AC Thomas   DA Warner             0  ...            bat
# 57072    NV Ojha  AC Thomas   DA Warner             0  ...            bat
#
#        winner     result  result_margin target_runs target_overs super_over  \
# ...

# %%
#Number of null values in target_overs column:
print("Null values in target_overs column :",ipl['target_overs'].isnull().sum())
# Out:
# Null values in target_overs column : 309

# %%
# filling null values with '0.0' 
# as the match is not played:
ipl['target_overs'].fillna(0.0,inplace=True)
# Out:
# C:\Users\clinton\AppData\Local\Temp\ipykernel_14332\1997267636.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ipl['target_overs'].fillna(0.0,inplace=True)

# %%
#Number of null values in target_overs column:
print("Null values in target_overs column after cleaning:",ipl['target_overs'].isnull().sum())
# Out:
# Null values in target_overs column after cleaning: 0

# %%
#-------------------

# %%
ipl.isnull().sum()[ipl.isnull().sum() > 0]
# Out:
# player_dismissed    247970
# dismissal_kind      247970
# fielder             251566
# city                 12397
# player_of_match        490
# winner                 490
# method              257274
# dtype: int64

# %%
ipl['method'].isnull().sum()
# Out:
# 257274

# %%
row=[ipl['method'].isnull().sum()]

# %%
print('null value percentage')
print(ipl['method'].isnull().sum()/row*100,'%')
# Out:
# null value percentage
# [100.] %

# %%
# viewing the rows without null values:
ipl[ipl['method'].isnull()==False]
# Out:
#         match_id  inning         batting_team     bowling_team  over  ball  \
# 9310      336022       1     Delhi Daredevils  Kings XI Punjab     0     1
# 9311      336022       1     Delhi Daredevils  Kings XI Punjab     0     2
# 9312      336022       1     Delhi Daredevils  Kings XI Punjab     0     3
# 9313      336022       1     Delhi Daredevils  Kings XI Punjab     0     4
# 9314      336022       1     Delhi Daredevils  Kings XI Punjab     0     5
# ...          ...     ...                  ...              ...   ...   ...
# 243812   1370353       2  Chennai Super Kings   Gujarat Titans    14     2
# 243813   1370353       2  Chennai Super Kings   Gujarat Titans    14     3
# 243814   1370353       2  Chennai Super Kings   Gujarat Titans    14     4
# 243815   1370353       2  Chennai Super Kings   Gujarat Titans    14     5
# 243816   1370353       2  Chennai Super Kings   Gujarat Titans    14     6
#
# ...

# %%
# filling with 'no D/L'
ipl['method'].fillna('no D/L',inplace=True)
# Out:
# C:\Users\clinton\AppData\Local\Temp\ipykernel_14332\2085173329.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ipl['method'].fillna('no D/L',inplace=True)

# %%
# Number of null values in method column:
print("Null values in method column after cleaning:",ipl['method'].isnull().sum())
# Out:
# Null values in method column after cleaning: 0

# %%
#-------------------------

# %%
# viewing null values in winner column (as rows):
ipl['winner']
ipl['winner'].isnull()
ipl[ipl['winner'].isnull()].head()
# Out:
#        match_id  inning      batting_team   bowling_team  over  ball  \
# 57068    501265       1  Delhi Daredevils  Pune Warriors     0     1
# 57069    501265       1  Delhi Daredevils  Pune Warriors     0     2
# 57070    501265       1  Delhi Daredevils  Pune Warriors     0     3
# 57071    501265       1  Delhi Daredevils  Pune Warriors     0     4
# 57072    501265       1  Delhi Daredevils  Pune Warriors     0     5
#
#           batter     bowler non_striker  batsman_runs  ...  toss_decision  \
# 57068    NV Ojha  AC Thomas   DA Warner             1  ...            bat
# 57069  DA Warner  AC Thomas     NV Ojha             0  ...            bat
# 57070    NV Ojha  AC Thomas   DA Warner             0  ...            bat
# 57071    NV Ojha  AC Thomas   DA Warner             0  ...            bat
# 57072    NV Ojha  AC Thomas   DA Warner             0  ...            bat
#
#        winner     result  result_margin target_runs target_overs super_over  \
# ...

# %%
#Number of null values in winner column:
print("Null values in winner column :",ipl['winner'].isnull().sum())
# Out:
# Null values in winner column : 490

# %%
# filling null vales in winner column
# with 'no result'
ipl['winner'].fillna('no result',inplace= True)
# Out:
# C:\Users\clinton\AppData\Local\Temp\ipykernel_14332\2696292175.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ipl['winner'].fillna('no result',inplace= True)

# %%
# Number of null values in winner column:
print("Null values in winner column after cleaning:",ipl['winner'].isnull().sum())
# Out:
# Null values in winner column after cleaning: 0

# %%
ipl.isnull().sum()[ipl.isnull().sum() > 0]
# Out:
# player_dismissed    247970
# dismissal_kind      247970
# fielder             251566
# city                 12397
# player_of_match        490
# dtype: int64

# %%
#----------------------------

# %%
# viewing null values in player_of_match column (as rows):
ipl['player_of_match']
ipl['player_of_match'].isnull()
ipl[ipl['player_of_match'].isnull()].head()
# Out:
#        match_id  inning      batting_team   bowling_team  over  ball  \
# 57068    501265       1  Delhi Daredevils  Pune Warriors     0     1
# 57069    501265       1  Delhi Daredevils  Pune Warriors     0     2
# 57070    501265       1  Delhi Daredevils  Pune Warriors     0     3
# 57071    501265       1  Delhi Daredevils  Pune Warriors     0     4
# 57072    501265       1  Delhi Daredevils  Pune Warriors     0     5
#
#           batter     bowler non_striker  batsman_runs  ...  toss_decision  \
# 57068    NV Ojha  AC Thomas   DA Warner             1  ...            bat
# 57069  DA Warner  AC Thomas     NV Ojha             0  ...            bat
# 57070    NV Ojha  AC Thomas   DA Warner             0  ...            bat
# 57071    NV Ojha  AC Thomas   DA Warner             0  ...            bat
# 57072    NV Ojha  AC Thomas   DA Warner             0  ...            bat
#
#           winner     result  result_margin target_runs target_overs  \
# ...

# %%
#Number of null values in player_of_match column:
print("Null values in player_of_match column :",ipl['player_of_match'].isnull().sum())
# Out:
# Null values in player_of_match column : 490

# %%
#filling null values
ipl['player_of_match'].fillna('no result',inplace=True)
# Out:
# C:\Users\clinton\AppData\Local\Temp\ipykernel_14332\3329456395.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ipl['player_of_match'].fillna('no result',inplace=True)

# %%
#Number of null values in player_of_match column:
print("Null values in player_of_match column after :",ipl['player_of_match'].isnull().sum())
# Out:
# Null values in player_of_match column after : 0

# %%
ipl.isnull().sum()[ipl.isnull().sum() > 0]
# Out:
# player_dismissed    247970
# dismissal_kind      247970
# fielder             251566
# city                 12397
# dtype: int64

# %%
# viewing null values in city column (as rows):
ipl['city'].isnull()
ipl[ipl['city'].isnull()].head()
# Out:
#        match_id  inning      batting_team                 bowling_team  over  \
# 94795    729281       1  Delhi Daredevils  Royal Challengers Bangalore     0
# 94796    729281       1  Delhi Daredevils  Royal Challengers Bangalore     0
# 94797    729281       1  Delhi Daredevils  Royal Challengers Bangalore     0
# 94798    729281       1  Delhi Daredevils  Royal Challengers Bangalore     0
# 94799    729281       1  Delhi Daredevils  Royal Challengers Bangalore     0
#
#        ball      batter    bowler non_striker  batsman_runs  ...  \
# 94795     1  MA Agarwal  MA Starc     M Vijay             0  ...
# 94796     2  MA Agarwal  MA Starc     M Vijay             0  ...
# 94797     3  MA Agarwal  MA Starc     M Vijay             2  ...
# 94798     4  MA Agarwal  MA Starc     M Vijay             0  ...
# 94799     5  MA Agarwal  MA Starc     M Vijay             1  ...
#
#        toss_decision                       winner   result  result_margin  \
# ...

# %%
# cleaning null values in city column:
# filling with requriements ('unknow')
ipl["city"]
ipl['city'].fillna('unknown')
# Out:
# 0         Bangalore
# 1         Bangalore
# 2         Bangalore
# 3         Bangalore
# 4         Bangalore
#             ...
# 260915      Chennai
# 260916      Chennai
# 260917      Chennai
# 260918      Chennai
# 260919      Chennai
# Name: city, Length: 260920, dtype: object

# %%
# cleaning null values in city column:
# filling with the maximum repeacted value (mode())
a=ipl["city"].mode()
print(a)
ipl["city"].fillna('Mumbai',inplace=True)
# Out:
# 0    Mumbai
# Name: city, dtype: object
# C:\Users\clinton\AppData\Local\Temp\ipykernel_14332\1187398782.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ipl["city"].fillna('Mumbai',inplace=True)

# %%
# check the null value after cleaning:
ipl['city'].isnull().sum()
# Out:
# 0

# %%
ipl.isnull().sum()[ipl.isnull().sum() > 0]
# Out:
# player_dismissed    247970
# dismissal_kind      247970
# fielder             251566
# dtype: int64

# %%
#-------------------------

# %% [markdown]
# ### #droping unnessary columns in ipl table

# %%
ipl.drop(columns=['player_dismissed','dismissal_kind','fielder'],inplace=True)

# %%
ipl.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'id', 'season', 'city',
#        'date', 'match_type', 'player_of_match', 'venue', 'team1', 'team2',
#        'toss_winner', 'toss_decision', 'winner', 'result', 'result_margin',
#        'target_runs', 'target_overs', 'super_over', 'method', 'umpire1',
#        'umpire2'],
#       dtype='object')

# %% [markdown]
# ### #changing the date column data_type --> object into date and time:

# %%
ipl['date']
# Out:
# 0         2008-04-18
# 1         2008-04-18
# 2         2008-04-18
# 3         2008-04-18
# 4         2008-04-18
#              ...
# 260915    2024-05-26
# 260916    2024-05-26
# 260917    2024-05-26
# 260918    2024-05-26
# 260919    2024-05-26
# Name: date, Length: 260920, dtype: object

# %%
ipl['date']=pd.to_datetime(ipl['date'],format='%Y-%m-%d') #changing the

# %%
ipl['date']
# Out:
# 0        2008-04-18
# 1        2008-04-18
# 2        2008-04-18
# 3        2008-04-18
# 4        2008-04-18
#             ...
# 260915   2024-05-26
# 260916   2024-05-26
# 260917   2024-05-26
# 260918   2024-05-26
# 260919   2024-05-26
# Name: date, Length: 260920, dtype: datetime64[ns]

# %%
#-----------------

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 34 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   match_id         260920 non-null  int64
#  1   inning           260920 non-null  category
#  2   batting_team     260920 non-null  category
#  3   bowling_team     260920 non-null  category
#  4   over             260920 non-null  category
#  5   ball             260920 non-null  category
#  6   batter           260920 non-null  object
#  7   bowler           260920 non-null  object
#  8   non_striker      260920 non-null  object
#  9   batsman_runs     260920 non-null  category
#  10  extra_runs       260920 non-null  category
#  11  total_runs       260920 non-null  category
#  12  extras_type      260920 non-null  category
#  13  is_wicket        260920 non-null  category
#  14  id               260920 non-null  int64
#  15  season           260920 non-null  object
# ...

# %%
ipl['season']=ipl['season'].astype('str')

# %%
a=0
for i in ipl['season']:
    if i =='2020/21':
        ipl['season'].iloc[a]='2020'
    a+=1

# %%
ipl['season'].unique()
# Out:
# array(['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023',
#        '2024'], dtype=object)

# %% [markdown]
# ## after the cleaning null values:

# %%
ipl.isnull().sum()
# Out:
# match_id           0
# inning             0
# batting_team       0
# bowling_team       0
# over               0
# ball               0
# batter             0
# bowler             0
# non_striker        0
# batsman_runs       0
# extra_runs         0
# total_runs         0
# extras_type        0
# is_wicket          0
# id                 0
# season             0
# city               0
# date               0
# match_type         0
# player_of_match    0
# venue              0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# target_runs        0
# target_overs       0
# super_over         0
# method             0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
ipl.nunique()
# Out:
# match_id           1095
# inning                6
# batting_team         19
# bowling_team         19
# over                 20
# ball                 11
# batter              673
# bowler              530
# non_striker         663
# batsman_runs          7
# extra_runs            7
# total_runs            8
# extras_type           6
# is_wicket             2
# id                 1095
# season               17
# city                 36
# date                823
# match_type            8
# player_of_match     292
# venue                58
# team1                19
# team2                19
# toss_winner          19
# toss_decision         2
# winner               20
# result                4
# result_margin        99
# target_runs         171
# target_overs         16
# super_over            2
# method                2
# umpire1              62
# umpire2              62
# dtype: int64

# %%
ipl['season']=ipl['season'].astype('category')

# %%
for i in ipl:
    print(i)
    print(ipl[i].nunique())
    if ipl[i].nunique()<40:
        ipl[i]=ipl[i].astype('category')
# Out:
# match_id
# 1095
# inning
# 6
# batting_team
# 19
# bowling_team
# 19
# over
# 20
# ball
# 11
# batter
# 673
# bowler
# 530
# non_striker
# 663
# batsman_runs
# 7
# extra_runs
# 7
# total_runs
# 8
# extras_type
# 6
# is_wicket
# 2
# id
# 1095
# season
# 17
# city
# 36
# date
# 823
# match_type
# 8
# player_of_match
# 292
# venue
# 58
# team1
# 19
# team2
# 19
# toss_winner
# 19
# toss_decision
# 2
# winner
# 20
# result
# 4
# result_margin
# 99
# target_runs
# 171
# target_overs
# 16
# super_over
# 2
# method
# 2
# umpire1
# 62
# umpire2
# 62

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 34 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   match_id         260920 non-null  int64
#  1   inning           260920 non-null  category
#  2   batting_team     260920 non-null  category
#  3   bowling_team     260920 non-null  category
#  4   over             260920 non-null  category
#  5   ball             260920 non-null  category
#  6   batter           260920 non-null  object
#  7   bowler           260920 non-null  object
#  8   non_striker      260920 non-null  object
#  9   batsman_runs     260920 non-null  category
#  10  extra_runs       260920 non-null  category
#  11  total_runs       260920 non-null  category
#  12  extras_type      260920 non-null  category
#  13  is_wicket        260920 non-null  category
#  14  id               260920 non-null  int64
#  15  season           260920 non-null  category
# ...

# %% [markdown]
# ## 5.EXPORT PROCESSED DATA FOR POWER BI

# %% [markdown]
# ## finaly cleaned ipl table converted into csv formate;

# %%
ipl.to_csv('ipl cricket analysis project.csv')

# %%
import os 
os.chdir("C:\\Users\\clinton\\OneDrive\\Desktop\\data set")
! dir
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 8426-E09B
#
#  Directory of C:\Users\clinton\OneDrive\Desktop\data set
#
# 22-03-2025  21:11    <DIR>          .
# 22-03-2025  23:57    <DIR>          ..
# 14-03-2025  23:12            19,751 Car Sales India 2024.xlsx
# 20-03-2025  13:15           240,745 cleaned ipl.csv
# 18-03-2025  19:20            10,790 COUNTRY.xlsx
# 18-03-2025  11:00             8,999 COUNTRYYY.xlsx
# 20-03-2025  17:36             9,061 count_ds.xlsx
# 18-03-2025  11:08        27,019,953 deliveries.csv
# 21-03-2025  10:54            76,813 employee_performance.csv
# 11-03-2025  15:39            25,211 filter data covid.csv
# 22-03-2025  22:23    <DIR>          ipl
# 24-03-2025  13:30        85,268,097 ipl cricket analysis project.csv
# 22-03-2025  21:09        85,268,097 ipl project.csv
# 18-03-2025  11:08           225,266 matches.csv
# 07-03-2025  23:51        23,738,470 Online Retail Data.xlsx
# 11-03-2025  16:25        48,233,998 only 2011.csv
# ...

# %% [markdown]
# ## 🏆 6.CONCLUSION

# %% [markdown]
# ### IPL Cricket Data Analysis Project
# In this project, we successfully analyzed IPL cricket data using Pandas for data processing and Power BI for visualization.
#
# 🔹 Key Takeaways:
#
# ✅ Data Cleaning & Preprocessing: We handled missing values, handled null values, removed duplicates, and transformed the dataset for meaningful insights.
# ✅ The IPL Cricket Data Analysis project is a powerful example of how data analytics and business intelligence can be leveraged to extract meaningful insights from sports data. By using Pandas for data processing and Power BI for visualization, we were able to analyze key trends, player performances, and match-winning strategies.
# ✅ This project proves the power of data-driven decision-making and can be an excellent addition to any portfolio or job interview in data analytics, business intelligence, or sports analytics.
